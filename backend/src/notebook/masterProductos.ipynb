# %%
import pandas as pd
import re
from rapidfuzz import fuzz, process

# %%
import pandas as pd
import re
from rapidfuzz import fuzz, process

# Función de limpieza de texto para una columna específica del DataFrame
def clear_column(column):
    """
    Limpia y normaliza el texto en una columna para eliminar términos irrelevantes y uniformar el formato.
    """
    # Eliminamos palabras irrelevantes como unidades, envases, etc.
    columna_limpia = re.sub(
        r'\b(\d+|mg|comp\.?|blisters?|estuche|x|ml|unidades|marca|botella|caja|referencia|cm|g|m|f\.a\.x|'
        r'jbe\.|sol\.|env\.|lata|vial|pvo\.|sobres|gotero|cápsulas|frascos?|blister|bot\.|mcg|sp|p\.b\.)\b', 
        '', 
        column, 
        flags=re.IGNORECASE
    )
    # Reemplazar saltos de línea por espacios
    columna_limpia = re.sub(r'\n', ' ', columna_limpia)
    columna_limpia = re.sub(r'[:\.\-,;()]', '', columna_limpia)
    columna_limpia = re.sub(r'\s+', ' ', columna_limpia).strip()
    columna_limpia = columna_limpia.lower()
    # Eliminamos palabras comunes (como 'de', 'la', etc.) que no ayudan a la comparación
    columna_limpia = re.sub(r'\b(?:de|la|el|en|a|y|con|para|del|sobre|por|medicamento|tratamiento|ac|se)\b', '', columna_limpia).strip()
    columna_limpia = re.sub(r'\b(\w+)\s+\1\b', r'\1', columna_limpia)
    # Aseguramos que unidades como mg, ml, etc. no interfieran
    columna_limpia = re.sub(r'\b(\d+mg|\d+g|\d+ml)\b', '', columna_limpia)
    return columna_limpia

# Función para cargar los datos desde un archivo CSV
def load_data(df_archivo):
    """
    Carga un archivo CSV en un DataFrame de pandas.
    """
    try:
        df = pd.read_csv(df_archivo)
        return df
    except Exception as e:
        print(f"Error al cargar el archivo {df_archivo}: {e}")
        return None

# Función para filtrar productos por laboratorio
def laboratorio_input_df(df, columna):
    """
    Busca coincidencias parciales en una columna de un DataFrame basado en una entrada del usuario.
    """
    input_name = input("Ingrese el nombre del laboratorio: ").strip()
    tablas_coincidencias = df[df[columna].str.contains(input_name, case=False, na=False)]

    if not tablas_coincidencias.empty:
        print(f"Se encontraron {len(tablas_coincidencias)} productos coincidentes del laboratorio '{input_name}'.")
        return tablas_coincidencias
    else:
        print(f"No se encontraron productos del laboratorio '{input_name}'.")
        return None

# Función para normalizar celdas con múltiples productos
def normalize_dataframe(df, column_to_split):
    """
    Normaliza un DataFrame separando celdas con múltiples productos en filas individuales.
    Args:
        df (pd.DataFrame): DataFrame original.
        column_to_split (str): Nombre de la columna a normalizar.
    Returns:
        pd.DataFrame: DataFrame normalizado con un producto por fila.
    """
    # Separar productos por múltiples delimitadores: saltos de línea, comas, puntos y comas, etc.
    df[column_to_split] = df[column_to_split].astype(str).str.split(r'[\n,;]+')  # Ahora cubre más delimitadores

    # Expandir las listas en múltiples filas
    df_normalized = df.explode(column_to_split, ignore_index=True)

    # Limpiar espacios extra en las celdas
    df_normalized[column_to_split] = df_normalized[column_to_split].str.strip()

    return df_normalized

# Función de comparación difusa
def comparar_similitud(texto1, texto2, umbral=80):
    """
    Compara dos textos utilizando similitud difusa (fuzzy matching) con un umbral configurable.
    """
    # Limpiar ambos textos antes de la comparación
    texto1_limpio = clear_column(texto1)
    texto2_limpio = clear_column(texto2)
    
    # Calcular la similitud entre los dos textos usando partial_ratio
    similitud = fuzz.partial_ratio(texto1_limpio, texto2_limpio)
    
    # Verificar si la similitud es mayor o igual al umbral
    return similitud >= umbral, similitud

# Cargar los datos desde archivos CSV
name_df_provedor = "prueba2.csv"  
name_df_productos = "L_STMaestroPrd.csv"  

df_proveedor = load_data(name_df_provedor)
df_productos = load_data(name_df_productos)

# Normalizar las columnas con múltiples productos
df_proveedor = normalize_dataframe(df_proveedor, 'DESCRIPCIÓN')
df_productos = normalize_dataframe(df_productos, 'descrip1')

# Copias de los DataFrames
copy_dfProductos = df_productos.loc[:, df_productos.notna().any()].copy()  # Eliminar columnas vacías
copy_dfProveedores = df_proveedor.copy()

# Limpiar las descripciones en ambas tablas
copy_dfProductos['descrip1_limpia'] = copy_dfProductos['descrip1'].fillna('').apply(clear_column)
copy_dfProveedores['descripcion_limpia'] = copy_dfProveedores['DESCRIPCIÓN'].fillna('').apply(clear_column)

# Filtrar los productos por laboratorio
columna_nombre = 'atrib0'  # Cambia por el nombre de la columna que contiene el laboratorio
laboratorio_coincidencias_df = laboratorio_input_df(copy_dfProductos, columna_nombre)

if laboratorio_coincidencias_df is not None:
    # Crear índice para búsqueda rápida
    proveedor_index = copy_dfProveedores['descripcion_limpia'].tolist()

    matches = []

    # Recorrer productos del proveedor y buscar todas las coincidencias con los productos del laboratorio
    for _, prov_row in copy_dfProveedores.iterrows():
        prov_desc = prov_row['descripcion_limpia']

        # Buscar todas las coincidencias que superen el umbral de similitud
        all_matches = process.extract(prov_desc, laboratorio_coincidencias_df['descrip1_limpia'], scorer=fuzz.partial_ratio, limit=None)
        valid_matches = [match for match in all_matches if match[1] >= 80]  # Filtrar por umbral de 80

        if valid_matches:
            for match in valid_matches:
                matched_row = laboratorio_coincidencias_df[ 
                    laboratorio_coincidencias_df['descrip1_limpia'] == match[0]
                ].iloc[0]  # Obtener la fila coincidente del laboratorio

                # Combinar la información del producto del proveedor y del laboratorio
                match_info = prov_row.to_dict()  # Información del proveedor
                match_info.update(matched_row.to_dict())  # Información del producto del laboratorio
                match_info['similaridad'] = match[1]  # Similaridad

                matches.append(match_info)
        else:
            # Si no hay coincidencia, incluir sólo la información del proveedor
            match_info = prov_row.to_dict()
            match_info['similaridad'] = 0  # Similaridad = 0

            # Agregar columnas vacías para los datos del laboratorio
            for col in laboratorio_coincidencias_df.columns:
                if col not in match_info:
                    match_info[col] = None

            matches.append(match_info)

    # Convertir la lista de matches a DataFrame
    df_matches = pd.DataFrame(matches)

    # Reordenar columnas para que 'similaridad' esté al principio
    cols = ['similaridad'] + [col for col in df_matches.columns if col != 'similaridad']
    df_matches = df_matches[cols]

    # Mostrar resultados
    print(f"\nCoincidencias encontradas: {len(df_matches[df_matches['similaridad'] > 0])}")
#
#                                    DESCRIPCIÓN  \
# 0                         HUMIRA AC x 2 (20mg)
# 1                         HUMIRA AC x 2 (20mg)
# 2                         HUMIRA AC x 2 (20mg)
# 3                         HUMIRA AC x 2 (20mg)
# 4                         HUMIRA AC x 2 (20mg)
# 5                         HUMIRA AC x 2 (20mg)
# 6   HUMIRA AC x 2 (40mg) HUMIRA AC x 1 (80 mg)
# 7                      RINVOQ 15MG RINVOQ 30MG
# 8                                  RINVOQ 45MG
# 9                                  RINVOQ 45MG
# 10                                 RINVOQ 45MG
# 11                             SKYRIZI SKYRIZI
# 12                             SKYRIZI SKYRIZI
# 13                             SKYRIZI SKYRIZI
# 14                             SKYRIZI SKYRIZI
# 15                                     SKYRIZI
# 16                                     SKYRIZI
# 17                                     SKYRIZI
# 18                                     SKYRIZI
# 19                            KALETRA SOLUCIÓN
# 20     KALETRA COMPRIMIDOS KALETRA COMPRIMIDOS
# 21     KALETRA COMPRIMIDOS KALETRA COMPRIMIDOS
# 22     KALETRA COMPRIMIDOS KALETRA COMPRIMIDOS
# 23                                   RITONAVIR
# 24                                     MAVIRET
# 25               VENCLEXTA VENCLEXTA VENCLEXTA
# 26               VENCLEXTA VENCLEXTA VENCLEXTA
# 27               VENCLEXTA VENCLEXTA VENCLEXTA
# 28                                   VENCLEXTA
# 29                                   VENCLEXTA
# 30                                   VENCLEXTA
# 31                                   VENCLEXTA
# 32                                    SEVORANE
# 33                                    SEVORANE
# 34                                    SEVORANE
# 35                         SEVORANE QUICK FILL
# 36                         SEVORANE QUICK FILL
# 37                         SEVORANE QUICK FILL
# 38                                    SURVANTA
# 39                                    SURVANTA
# 40                                    SURVANTA
# 41                                    SURVANTA
# 42                                ZEMPLAR VIAL
# 43                                ZEMPLAR VIAL
# 44                                ZEMPLAR VIAL
# 45                               ZEMPLAR 2 MCG
# 46                               ZEMPLAR 2 MCG
# 47                               ZEMPLAR 2 MCG
# 48                                       BOTOX
# 49                                       BOTOX
# 50                                       BOTOX
# 51                                       BOTOX
# 52                                     OZURDEX
#
#                                          PRESENTACION  \
# 0   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 1   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 2   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 3   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 4   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 5   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 6   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 7   15 MG x 30 COMP REC DE LIB. PROLONGADA\n30 MG ...
# 8   15 MG x 30 COMP REC DE LIB. PROLONGADA\n30 MG ...
# 9   15 MG x 30 COMP REC DE LIB. PROLONGADA\n30 MG ...
# 10  15 MG x 30 COMP REC DE LIB. PROLONGADA\n30 MG ...
# 11  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 12  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 13  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 14  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 15  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 16  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 17  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 18  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 19  160 ML\n60 COMP. RECUBIERTOS\n120 COMP. RECUBI...
# 20  160 ML\n60 COMP. RECUBIERTOS\n120 COMP. RECUBI...
# 21  160 ML\n60 COMP. RECUBIERTOS\n120 COMP. RECUBI...
# 22  160 ML\n60 COMP. RECUBIERTOS\n120 COMP. RECUBI...
# 23                                     30 COMPRIMIDOS
# 24                         100 MG/40 MG x 84 COMP REC
# 25  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 26  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 27  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 28  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 29  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 30  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 31  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 32                                     250 ML\n250 ML
# 33                                     250 ML\n250 ML
# 34                                     250 ML\n250 ML
# 35                                     250 ML\n250 ML
# 36                                     250 ML\n250 ML
# 37                                     250 ML\n250 ML
# 38                                         4 ML\n8 ML
# 39                                         4 ML\n8 ML
# 40                                         4 ML\n8 ML
# 41                                         4 ML\n8 ML
# 42                              5 VIALES\n30 CAPSULAS
# 43                              5 VIALES\n30 CAPSULAS
# 44                              5 VIALES\n30 CAPSULAS
# 45                              5 VIALES\n30 CAPSULAS
# 46                              5 VIALES\n30 CAPSULAS
# 9   $         1,799,606.71\n$         3,184,521.02...
# 10  $         1,799,606.71\n$         3,184,521.02...
# 11  $         4,344,159.74\n$         4,561,367.72...
# 12  $         4,344,159.74\n$         4,561,367.72...
# 13  $         4,344,159.74\n$         4,561,367.72...
# 14  $         4,344,159.74\n$         4,561,367.72...
# 15  $         4,344,159.74\n$         4,561,367.72...
# 16  $         4,344,159.74\n$         4,561,367.72...
# 17  $         4,344,159.74\n$         4,561,367.72...
# 18  $         4,344,159.74\n$         4,561,367.72...
# 19  $             148,177.93\n$            138,771...
# 20  $             148,177.93\n$            138,771...
# 21  $             148,177.93\n$            138,771...
# 22  $             148,177.93\n$            138,771...
# 23                                        $ 25.166,11
# 24                                     $ 9.150.200,87
# 25  $         2,420,724.48\n$       11,215,990.12\...
# 26  $         2,420,724.48\n$       11,215,990.12\...
# 27  $         2,420,724.48\n$       11,215,990.12\...
# 28  $         2,420,724.48\n$       11,215,990.12\...
# 29  $         2,420,724.48\n$       11,215,990.12\...
# 30  $         2,420,724.48\n$       11,215,990.12\...
# 31  $         2,420,724.48\n$       11,215,990.12\...
# 32  $             158,394.74\n$             158,39...
# 33  $             158,394.74\n$             158,39...
# 34  $             158,394.74\n$             158,39...
# 35  $             158,394.74\n$             158,39...
# 36  $             158,394.74\n$             158,39...
# 37  $             158,394.74\n$             158,39...
# 38  $                            -\n$             ...
# 39  $                            -\n$             ...
# 40  $                            -\n$             ...
# 41  $                            -\n$             ...
# 42  $             115,907.78\n$             254,57...
# 43  $             115,907.78\n$             254,57...
# 44  $             115,907.78\n$             254,57...
# 45  $             115,907.78\n$             254,57...
# 46  $             115,907.78\n$             254,57...
# 47  $             115,907.78\n$             254,57...
# 48  $             222,779.33\n$             432,19...
# 49  $             222,779.33\n$             432,19...
# 50  $             222,779.33\n$             432,19...
# 51  $             222,779.33\n$             432,19...
# 52                                     $ 1.291.438,06
#
#                                        PRECIO SIN IVA  \
# 0   $             611,690.58\n$          1,223,382...
# 1   $             611,690.58\n$          1,223,382...
# 2   $             611,690.58\n$          1,223,382...
# 3   $             611,690.58\n$          1,223,382...
# 4   $             611,690.58\n$          1,223,382...
# 5   $             611,690.58\n$          1,223,382...
# 6   $             611,690.58\n$          1,223,382...
# 7   $          1,487,278.28\n$          2,631,835....
# 8   $          1,487,278.28\n$          2,631,835....
# 9   $          1,487,278.28\n$          2,631,835....
# 10  $          1,487,278.28\n$          2,631,835....
# 11  $          3,590,214.67\n$          3,769,725....
# 12  $          3,590,214.67\n$          3,769,725....
# 13  $          3,590,214.67\n$          3,769,725....
# 14  $          3,590,214.67\n$          3,769,725....
# 15  $          3,590,214.67\n$          3,769,725....
# 16  $          3,590,214.67\n$          3,769,725....
# 17  $          3,590,214.67\n$          3,769,725....
# 18  $          3,590,214.67\n$          3,769,725....
# 19  $             122,461.09\n$            114,686...
# 20  $             122,461.09\n$            114,686...
# 21  $             122,461.09\n$            114,686...
# 22  $             122,461.09\n$            114,686...
# 23                                        $ 20.798,42
# 24                                     $ 7.562.149,48
# 25  $          2,000,598.69\n$          9,269,413....
# 26  $          2,000,598.69\n$          9,269,413....
# 27  $          2,000,598.69\n$          9,269,413....
# 28  $          2,000,598.69\n$          9,269,413....
# 29  $          2,000,598.69\n$          9,269,413....
# 30  $          2,000,598.69\n$          9,269,413....
# 31  $          2,000,598.69\n$          9,269,413....
# 32  $             130,904.73\n$             130,90...
# 33  $             130,904.73\n$             130,90...
# 34  $             130,904.73\n$             130,90...
# 35  $             130,904.73\n$             130,90...
# 36  $             130,904.73\n$             130,90...
# 37  $             130,904.73\n$             130,90...
# 38  $                            -\n$             ...
# 39  $                            -\n$             ...
# 40  $                            -\n$             ...
# 41  $                            -\n$             ...
# 42  $               95,791.56\n$             210,3...
# 43  $               95,791.56\n$             210,3...
# 44  $               95,791.56\n$             210,3...
# 45  $               95,791.56\n$             210,3...
# 46  $               95,791.56\n$             210,3...
# 47  $               95,791.56\n$             210,3...
# 48  $             184,115.15\n$             357,18...
# 49  $             184,115.15\n$             357,18...
# 50  $             184,115.15\n$             357,18...
# 51  $             184,115.15\n$             357,18...
# 52                                     $ 1.067.304,19
#
#                                     PUBLICO\nSUGERIDO  \
# 0   $           1,073,211.02\n$           2,146,42...
# 1   $           1,073,211.02\n$           2,146,42...
# 2   $           1,073,211.02\n$           2,146,42...
# 3   $           1,073,211.02\n$           2,146,42...
# 4   $           1,073,211.02\n$           2,146,42...
# 5   $           1,073,211.02\n$           2,146,42...
# 6   $           1,073,211.02\n$           2,146,42...
# 7   $           2,609,429.58\n$           4,617,55...
# 8   $           2,609,429.58\n$           4,617,55...
# 9   $           2,609,429.58\n$           4,617,55...
# 10  $           2,609,429.58\n$           4,617,55...
# 11  $           6,299,031.64\n$           6,613,98...
# 12  $           6,299,031.64\n$           6,613,98...
# 13  $           6,299,031.64\n$           6,613,98...
# 14  $           6,299,031.64\n$           6,613,98...
# 15  $           6,299,031.64\n$           6,613,98...
# 16  $           6,299,031.64\n$           6,613,98...
# 17  $           6,299,031.64\n$           6,613,98...
# 18  $           6,299,031.64\n$           6,613,98...
# 19  $              214,857.98\n$              201,...
# 20  $              214,857.98\n$              201,...
# 21  $              214,857.98\n$              201,...
# 22  $              214,857.98\n$              201,...
# 23                                        $ 36.490,79
# 24                                    $ 13.267.791,31
# 25  $           3,510,050.42\n$        16,263,185....
# 26  $           3,510,050.42\n$        16,263,185....
# 27  $           3,510,050.42\n$        16,263,185....
# 28  $           3,510,050.42\n$        16,263,185....
# 29  $           3,510,050.42\n$        16,263,185....
# 30  $           3,510,050.42\n$        16,263,185....
# 31  $           3,510,050.42\n$        16,263,185....
# 32  $              229,672.36\n$              229,...
# 33  $              229,672.36\n$              229,...
# 34  $              229,672.36\n$              229,...
# 35  $              229,672.36\n$              229,...
# 36  $              229,672.36\n$              229,...
# 37  $              229,672.36\n$              229,...
# 38  $              173,354.12\n$              260,...
# 39  $              173,354.12\n$              260,...
# 40  $              173,354.12\n$              260,...
# 41  $              173,354.12\n$              260,...
# 42  $              168,066.22\n$              369,...
# 43  $              168,066.22\n$              369,...
# 44  $              168,066.22\n$              369,...
# 45  $              168,066.22\n$              369,...
# 46  $              168,066.22\n$              369,...
# 47  $              168,066.22\n$              369,...
# 48  $              323,029.99\n$              626,...
# 49  $              323,029.99\n$              626,...
# 50  $              323,029.99\n$              626,...
# 51  $              323,029.99\n$              626,...
# 52                                     $ 1.872.585,02
#
#                          descripcion_limpia    niprod  ... tipo_egreso  \
# 0                                  humira    119550.0  ...           E
# 1                                  humira    119551.0  ...           E
# 2                                  humira    119550.0  ...           E
# 3                                  humira    119549.0  ...           E
# 4                                  humira    119553.0  ...           E
# 5                                  humira    119554.0  ...           E
# 6                           humira   humira       NaN  ...        None
# 7                           rinvoq  rinvoq        NaN  ...        None
# 8                                   rinvoq   119559.0  ...           E
# 9                                   rinvoq   119559.0  ...           E
# 10                                  rinvoq   119559.0  ...           E
# 11                                  skyrizi  124898.0  ...           E
# 12                                  skyrizi  130997.0  ...           E
# 13                                  skyrizi  130998.0  ...           E
# 14                                  skyrizi  119565.0  ...           E
# 15                                  skyrizi  124898.0  ...           E
# 16                                  skyrizi  130997.0  ...           E
# 17                                  skyrizi  130998.0  ...           E
# 18                                  skyrizi  119565.0  ...           E
# 19                         kaletra solución  119557.0  ...           E
# 20  kaletra comprimidos kaletra comprimidos  119557.0  ...           E
# 21  kaletra comprimidos kaletra comprimidos  119555.0  ...           E
# 22  kaletra comprimidos kaletra comprimidos  119555.0  ...           E
# 23                                ritonavir  119560.0  ...           E
# 24                                  maviret  119558.0  ...           E
# 25                      venclexta venclexta  119572.0  ...           E
# 26                      venclexta venclexta  119572.0  ...           E
# 27                      venclexta venclexta  119572.0  ...           E
# 28                                venclexta  119572.0  ...           E
# 29                                venclexta  119572.0  ...           E
# 30                                venclexta  119572.0  ...           E
# 31                                venclexta  119575.0  ...           E
# 32                                 sevorane  119561.0  ...           E
# 33                                 sevorane  119561.0  ...           E
# 34                                 sevorane  119563.0  ...           E
# 35                      sevorane quick fill  119561.0  ...           E
# 36                      sevorane quick fill  119561.0  ...           E
# 37                      sevorane quick fill  119563.0  ...           E
# 38                                 survanta  119566.0  ...           E
# 39                                 survanta  119566.0  ...           E
# 40                                 survanta  119566.0  ...           E
# 41                                 survanta  119566.0  ...           E
# 42                                  zemplar  119577.0  ...           E
# 43                                  zemplar  119578.0  ...           E
# 44                                  zemplar  119578.0  ...           E
# 45                                  zemplar  119577.0  ...           E
# 46                                  zemplar  119578.0  ...           E
# 47                                  zemplar  119578.0  ...           E
# 48                                    botox   23432.0  ...           E
# 49                                    botox   23432.0  ...           E
# 50                                    botox   23432.0  ...           E
# 51                                    botox   23432.0  ...           E
# 52                                  ozurdex   23459.0  ...           E
#
#    pc_diftrans cod_cvta cat_item cant_rep pto_rep           atrib0 atrib1  \
# 0          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 1          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 2          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 3          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 4          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 5          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 6          NaN      NaN     None     None     NaN             None    NaN
# 7          NaN      NaN     None     None     NaN             None    NaN
# 8          0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 9          0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 10         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 11         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 12         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 13         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 14         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 15         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 16         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 17         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 18         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 19         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 20         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 21         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 22         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 23         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 24         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 25         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 26         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 27         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 28         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 29         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 30         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 31         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 32         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 33         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 34         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 35         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 36         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 37         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 38         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 39         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 40         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 41         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 42         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 43         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 44         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 45         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 46         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 47         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 48         0.0      NaN    ITGEV        0     0.0  ABBVIE ALLERGAN    NaN
# 49         0.0      NaN    ITGEV        0     0.0  ABBVIE ALLERGAN    NaN
# 50         0.0      NaN    ITGEV        0     0.0  ABBVIE ALLERGAN    NaN
# 51         0.0      NaN    ITGEV        0     0.0  ABBVIE ALLERGAN    NaN
# 52         0.0      NaN    ITGEV      0.0     0.0  ABBVIE ALLERGAN    NaN
#
#    atrib2                  descrip1_limpia
# 0     NaN               humira  / lapprell
# 1     NaN               humira  / jerprell
# 2     NaN               humira  / lapprell
# 3     NaN                  humira jgaprell
# 4     NaN                humira pediatrico
# 5     NaN              humira pen lapicera
# 6     NaN                             None
# 7     NaN                             None
# 8     NaN                   rinvoq libprol
# 9     NaN                   rinvoq libprol
# 10    NaN                   rinvoq libprol
# 11    NaN                 skyrizi lapprell
# 12    NaN               skyrizi cart + iny
# 13    NaN                          skyrizi
# 14    NaN                 skyrizi jgaprell
# 15    NaN                 skyrizi lapprell
# 16    NaN               skyrizi cart + iny
# 17    NaN                          skyrizi
# 18    NaN                 skyrizi jgaprell
# 19    NaN                          kaletra
# 20    NaN                          kaletra
# 21    NaN                    kaletra / rec
# 22    NaN                    kaletra / rec
# 23    NaN                    ritonavir rec
# 24    NaN                      maviret rec
# 25    NaN                        venclexta
# 26    NaN                        venclexta
# 27    NaN                        venclexta
# 28    NaN                        venclexta
# 29    NaN                        venclexta
# 30    NaN                        venclexta
# 31    NaN            venclexta kit  inicio
# 32    NaN                         sevorane
# 33    NaN                         sevorane
# 34    NaN              sevorane quick fill
# 35    NaN                         sevorane
# 36    NaN                         sevorane
# 37    NaN              sevorane quick fill
# 38    NaN                         survanta
# 39    NaN                         survanta
# 40    NaN                         survanta
# 41    NaN                         survanta
# 42    NaN                     zemplar cáps
# 43    NaN                          zemplar
# 44    NaN                          zemplar
# 45    NaN                     zemplar cáps
# 46    NaN                          zemplar
# 47    NaN                          zemplar
# 48    NaN                          botox u
# 49    NaN                          botox u
# 50    NaN                          botox u
# 51    NaN                          botox u
# 52    NaN  ozurdex implante oftintravítrea
#
# [53 rows x 56 columns]
#
# Productos del laboratorio sin coincidencias: 67
#         niprod cod_prod cod_abrev                          descrip1 descrip2  \
# 790    23422.0    38945     38945          ACULAR LS sol.oft.x 5 ml      NaN
# 791    23421.0    15467     15467             ACULAR sol.oft.x 5 ml      NaN
# 793    23423.0    48009     48009  ACUVAIL viales unids.x 30 x0.4ml      NaN
# 1658   23424.0    44172     44172             AIBREX sol.oft.x 5 ml      NaN
# 2443   23427.0    31189     31189         ALPHAGAN P sol.oft.x 5 ml      NaN
# ...        ...      ...       ...                               ...      ...
# 55336  23478.0     5197      5197       VISTACLORAM gts.oft.x 10 ml      NaN
# 55338  23479.0    20487     20487          VISUBRIL colirio x 15 ml      NaN
# 56974  23480.0    34168     34168       ZYMARAN 0.3% sol.oft.x 5 ml      NaN
# 56975  23481.0    47867     47867         ZYMAXID fco.gotero x 5 ml      NaN
# 56976  23482.0    48712     48712            ZYPRED susp.oft.x 6 ml      NaN
#
#                       abrev cod_catprod         codbarra cod_fbarra unid_v  \
# 790     ACULAR LS sol.oft.x          PT    8054083026008        NaN     UN
# 791    ACULAR sol.oft.x 5 m          PT    8054083026329        NaN     UN
# 793    ACUVAIL viales unids          PT    7795316000099        NaN     UN
# 1658   AIBREX sol.oft.x 5 m          PT    7795316000112        NaN     UN
# 2443   ALPHAGAN P sol.oft.x          PT    8054083026312        NaN     UN
# ...                     ...         ...              ...        ...    ...
# 55336  VISTACLORAM gts.oft.          PT  7795316130130.0        NaN     UN
# 55338  VISUBRIL colirio x 1          PT  7795316907671.0        NaN     UN
# 56974  ZYMARAN 0.3% sol.oft          PT  8054083026336.0        NaN     UN
# 56975  ZYMAXID fco.gotero x          PT  8054083026350.0        NaN     UN
# 56976   ZYPRED susp.oft.x 6          PT  8054083026190.0        NaN     UN
#
#        ...  tipo_egreso pc_diftrans cod_cvta cat_item cant_rep pto_rep  \
# 790    ...            E         0.0      NaN    ITGEV        0     0.0
# 791    ...            E         0.0      NaN    ITGEV        0     0.0
# 793    ...            E         0.0      NaN    ITGEV        0     0.0
# 1658   ...            E         0.0      NaN    ITGEV        0     0.0
# 2443   ...            E         0.0      NaN    ITGEV        0     0.0
# ...    ...          ...         ...      ...      ...      ...     ...
# 55336  ...            E         0.0      NaN    ITGEV        0     0.0
# 55338  ...            E         0.0      NaN    ITGEV        0     0.0
# 56974  ...            E         0.0      NaN    ITGEV        0     0.0
# 56975  ...            E         0.0      NaN    ITGEV        0     0.0
# 56976  ...            E         0.0      NaN    ITGEV        0     0.0
#
#                 atrib0 atrib1 atrib2             descrip1_limpia
# 790    ABBVIE ALLERGAN    NaN    NaN               acular ls oft
# 791    ABBVIE ALLERGAN    NaN    NaN                  acular oft
# 793    ABBVIE ALLERGAN    NaN    NaN  acuvail viales unids x04ml
# 1658   ABBVIE ALLERGAN    NaN    NaN                  aibrex oft
# 2443   ABBVIE ALLERGAN    NaN    NaN              alphagan p oft
# ...                ...    ...    ...                         ...
# 55336  ABBVIE ALLERGAN    NaN    NaN          vistacloram gtsoft
# 55338  ABBVIE ALLERGAN    NaN    NaN            visubril colirio
# 56974  ABBVIE ALLERGAN    NaN    NaN               zymaran % oft
# 56975  ABBVIE ALLERGAN    NaN    NaN                 zymaxid fco
# 56976  ABBVIE ALLERGAN    NaN    NaN              zypred suspoft
#
# [67 rows x 47 columns]

# %%
df_matches
# Out:
#     similaridad                              Unnamed: 0  \
# 0    100.000000            20015888\n20005289\n20021980
# 1    100.000000            20015888\n20005289\n20021980
# 2    100.000000            20015888\n20005289\n20021980
# 3     93.333333            20015888\n20005289\n20021980
# 4     93.333333            20015888\n20005289\n20021980
# 5     93.333333            20015888\n20005289\n20021980
# 6      0.000000            20015888\n20005289\n20021980
# 7      0.000000            20062091\n20069005\n20078725
# 8    100.000000            20062091\n20069005\n20078725
# 9    100.000000            20062091\n20069005\n20078725
# 25               VENCLEXTA VENCLEXTA VENCLEXTA
# 26               VENCLEXTA VENCLEXTA VENCLEXTA
# 27               VENCLEXTA VENCLEXTA VENCLEXTA
# 28                                   VENCLEXTA
# 29                                   VENCLEXTA
# 30                                   VENCLEXTA
# 31                                   VENCLEXTA
# 32                                    SEVORANE
# 33                                    SEVORANE
# 34                                    SEVORANE
# 35                         SEVORANE QUICK FILL
# 36                         SEVORANE QUICK FILL
# 37                         SEVORANE QUICK FILL
# 38                                    SURVANTA
# 39                                    SURVANTA
# 40                                    SURVANTA
# 41                                    SURVANTA
# 42                                ZEMPLAR VIAL
# 43                                ZEMPLAR VIAL
# 44                                ZEMPLAR VIAL
# 45                               ZEMPLAR 2 MCG
# 46                               ZEMPLAR 2 MCG
# 47                               ZEMPLAR 2 MCG
# 48                                       BOTOX
# 49                                       BOTOX
# 50                                       BOTOX
# 51                                       BOTOX
# 52                                     OZURDEX
#
#                                          PRESENTACION  \
# 0   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 1   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 2   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 3   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 4   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 5   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 6   2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 7   15 MG x 30 COMP REC DE LIB. PROLONGADA\n30 MG ...
# 8   15 MG x 30 COMP REC DE LIB. PROLONGADA\n30 MG ...
# 9   15 MG x 30 COMP REC DE LIB. PROLONGADA\n30 MG ...
# 10  15 MG x 30 COMP REC DE LIB. PROLONGADA\n30 MG ...
# 11  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 12  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 13  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 14  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 15  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 16  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 17  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 18  1 LAPICERA PRELLENADA por 1 ML (150 mg)\n360mg...
# 19  160 ML\n60 COMP. RECUBIERTOS\n120 COMP. RECUBI...
# 20  160 ML\n60 COMP. RECUBIERTOS\n120 COMP. RECUBI...
# 21  160 ML\n60 COMP. RECUBIERTOS\n120 COMP. RECUBI...
# 22  160 ML\n60 COMP. RECUBIERTOS\n120 COMP. RECUBI...
# 23                                     30 COMPRIMIDOS
# 24                         100 MG/40 MG x 84 COMP REC
# 25  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 26  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 27  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 28  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 29  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 30  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 31  KIT DE INICIO X 1 - PACK 4X7 DIAS 100 MG X 120...
# 32                                     250 ML\n250 ML
# 33                                     250 ML\n250 ML
# 34                                     250 ML\n250 ML
# 35                                     250 ML\n250 ML
# 36                                     250 ML\n250 ML
# 37                                     250 ML\n250 ML
# 38                                         4 ML\n8 ML
# 39                                         4 ML\n8 ML
# 40                                         4 ML\n8 ML
# 41                                         4 ML\n8 ML
# 42                              5 VIALES\n30 CAPSULAS
# 43                              5 VIALES\n30 CAPSULAS
# 44                              5 VIALES\n30 CAPSULAS
# 45                              5 VIALES\n30 CAPSULAS
# 46                              5 VIALES\n30 CAPSULAS
# 47                              5 VIALES\n30 CAPSULAS
# 48                             Vial 100 U\nVial 200 U
# 49                             Vial 100 U\nVial 200 U
# 50                             Vial 100 U\nVial 200 U
# 51                             Vial 100 U\nVial 200 U
# 52                                         0.7 MG C/1
#
#                                      CODIGO DE BARRAS  \
# 0         8054083017068\n8054083014050\n8054083017648
# 1         8054083017068\n8054083014050\n8054083017648
# 2         8054083017068\n8054083014050\n8054083017648
# 3         8054083017068\n8054083014050\n8054083017648
# 4         8054083017068\n8054083014050\n8054083017648
# 5         8054083017068\n8054083014050\n8054083017648
# 6         8054083017068\n8054083014050\n8054083017648
# 7         8054083018706\n8054083021386\n8054083023922
# 8         8054083018706\n8054083021386\n8054083023922
# 9         8054083018706\n8054083021386\n8054083023922
# 10        8054083018706\n8054083021386\n8054083023922
# 11        8054083021935\n8054083023311\n8054083023328
# 12        8054083021935\n8054083023311\n8054083023328
# 13        8054083021935\n8054083023311\n8054083023328
# 29  $         2,420,724.48\n$       11,215,990.12\...
# 30  $         2,420,724.48\n$       11,215,990.12\...
# 31  $         2,420,724.48\n$       11,215,990.12\...
# 32  $             158,394.74\n$             158,39...
# 33  $             158,394.74\n$             158,39...
# 34  $             158,394.74\n$             158,39...
# 35  $             158,394.74\n$             158,39...
# 36  $             158,394.74\n$             158,39...
# 37  $             158,394.74\n$             158,39...
# 38  $                            -\n$             ...
# 39  $                            -\n$             ...
# 40  $                            -\n$             ...
# 41  $                            -\n$             ...
# 42  $             115,907.78\n$             254,57...
# 43  $             115,907.78\n$             254,57...
# 44  $             115,907.78\n$             254,57...
# 45  $             115,907.78\n$             254,57...
# 46  $             115,907.78\n$             254,57...
# 47  $             115,907.78\n$             254,57...
# 48  $             222,779.33\n$             432,19...
# 49  $             222,779.33\n$             432,19...
# 50  $             222,779.33\n$             432,19...
# 51  $             222,779.33\n$             432,19...
# 52                                     $ 1.291.438,06
#
#                                        PRECIO SIN IVA  \
# 0   $             611,690.58\n$          1,223,382...
# 1   $             611,690.58\n$          1,223,382...
# 2   $             611,690.58\n$          1,223,382...
# 3   $             611,690.58\n$          1,223,382...
# 4   $             611,690.58\n$          1,223,382...
# 5   $             611,690.58\n$          1,223,382...
# 6   $             611,690.58\n$          1,223,382...
# 7   $          1,487,278.28\n$          2,631,835....
# 8   $          1,487,278.28\n$          2,631,835....
# 9   $          1,487,278.28\n$          2,631,835....
# 10  $          1,487,278.28\n$          2,631,835....
# 11  $          3,590,214.67\n$          3,769,725....
# 12  $          3,590,214.67\n$          3,769,725....
# 13  $          3,590,214.67\n$          3,769,725....
# 14  $          3,590,214.67\n$          3,769,725....
# 15  $          3,590,214.67\n$          3,769,725....
# 16  $          3,590,214.67\n$          3,769,725....
# 17  $          3,590,214.67\n$          3,769,725....
# 18  $          3,590,214.67\n$          3,769,725....
# 19  $             122,461.09\n$            114,686...
# 20  $             122,461.09\n$            114,686...
# 21  $             122,461.09\n$            114,686...
# 22  $             122,461.09\n$            114,686...
# 23                                        $ 20.798,42
# 24                                     $ 7.562.149,48
# 25  $          2,000,598.69\n$          9,269,413....
# 26  $          2,000,598.69\n$          9,269,413....
# 27  $          2,000,598.69\n$          9,269,413....
# 28  $          2,000,598.69\n$          9,269,413....
# 29  $          2,000,598.69\n$          9,269,413....
# 30  $          2,000,598.69\n$          9,269,413....
# 31  $          2,000,598.69\n$          9,269,413....
# 32  $             130,904.73\n$             130,90...
# 33  $             130,904.73\n$             130,90...
# 34  $             130,904.73\n$             130,90...
# 35  $             130,904.73\n$             130,90...
# 36  $             130,904.73\n$             130,90...
# 37  $             130,904.73\n$             130,90...
# 38  $                            -\n$             ...
# 39  $                            -\n$             ...
# 40  $                            -\n$             ...
# 41  $                            -\n$             ...
# 42  $               95,791.56\n$             210,3...
# 43  $               95,791.56\n$             210,3...
# 44  $               95,791.56\n$             210,3...
# 45  $               95,791.56\n$             210,3...
# 46  $               95,791.56\n$             210,3...
# 47  $               95,791.56\n$             210,3...
# 48  $             184,115.15\n$             357,18...
# 49  $             184,115.15\n$             357,18...
# 50  $             184,115.15\n$             357,18...
# 51  $             184,115.15\n$             357,18...
# 52                                     $ 1.067.304,19
#
#                                     PUBLICO\nSUGERIDO  \
# 0   $           1,073,211.02\n$           2,146,42...
# 1   $           1,073,211.02\n$           2,146,42...
# 2   $           1,073,211.02\n$           2,146,42...
# 3   $           1,073,211.02\n$           2,146,42...
# 4   $           1,073,211.02\n$           2,146,42...
# 5   $           1,073,211.02\n$           2,146,42...
# 6   $           1,073,211.02\n$           2,146,42...
# 7   $           2,609,429.58\n$           4,617,55...
# 8   $           2,609,429.58\n$           4,617,55...
# 9   $           2,609,429.58\n$           4,617,55...
# 10  $           2,609,429.58\n$           4,617,55...
# 11  $           6,299,031.64\n$           6,613,98...
# 12  $           6,299,031.64\n$           6,613,98...
# 13  $           6,299,031.64\n$           6,613,98...
# 14  $           6,299,031.64\n$           6,613,98...
# 15  $           6,299,031.64\n$           6,613,98...
# 16  $           6,299,031.64\n$           6,613,98...
# 17  $           6,299,031.64\n$           6,613,98...
# 18  $           6,299,031.64\n$           6,613,98...
# 19  $              214,857.98\n$              201,...
# 20  $              214,857.98\n$              201,...
# 21  $              214,857.98\n$              201,...
# 22  $              214,857.98\n$              201,...
# 23                                        $ 36.490,79
# 24                                    $ 13.267.791,31
# 25  $           3,510,050.42\n$        16,263,185....
# 26  $           3,510,050.42\n$        16,263,185....
# 27  $           3,510,050.42\n$        16,263,185....
# 28  $           3,510,050.42\n$        16,263,185....
# 29  $           3,510,050.42\n$        16,263,185....
# 30  $           3,510,050.42\n$        16,263,185....
# 31  $           3,510,050.42\n$        16,263,185....
# 32  $              229,672.36\n$              229,...
# 33  $              229,672.36\n$              229,...
# 34  $              229,672.36\n$              229,...
# 35  $              229,672.36\n$              229,...
# 36  $              229,672.36\n$              229,...
# 37  $              229,672.36\n$              229,...
# 38  $              173,354.12\n$              260,...
# 39  $              173,354.12\n$              260,...
# 40  $              173,354.12\n$              260,...
# 41  $              173,354.12\n$              260,...
# 42  $              168,066.22\n$              369,...
# 43  $              168,066.22\n$              369,...
# 44  $              168,066.22\n$              369,...
# 45  $              168,066.22\n$              369,...
# 46  $              168,066.22\n$              369,...
# 47  $              168,066.22\n$              369,...
# 48  $              323,029.99\n$              626,...
# 49  $              323,029.99\n$              626,...
# 50  $              323,029.99\n$              626,...
# 51  $              323,029.99\n$              626,...
# 52                                     $ 1.872.585,02
#
#                          descripcion_limpia    niprod  ... tipo_egreso  \
# 0                                  humira    119550.0  ...           E
# 1                                  humira    119551.0  ...           E
# 2                                  humira    119550.0  ...           E
# 3                                  humira    119549.0  ...           E
# 4                                  humira    119553.0  ...           E
# 5                                  humira    119554.0  ...           E
# 6                           humira   humira       NaN  ...        None
# 7                           rinvoq  rinvoq        NaN  ...        None
# 8                                   rinvoq   119559.0  ...           E
# 9                                   rinvoq   119559.0  ...           E
# 10                                  rinvoq   119559.0  ...           E
# 11                                  skyrizi  124898.0  ...           E
# 12                                  skyrizi  130997.0  ...           E
# 13                                  skyrizi  130998.0  ...           E
# 14                                  skyrizi  119565.0  ...           E
# 15                                  skyrizi  124898.0  ...           E
# 16                                  skyrizi  130997.0  ...           E
# 17                                  skyrizi  130998.0  ...           E
# 18                                  skyrizi  119565.0  ...           E
# 19                         kaletra solución  119557.0  ...           E
# 20  kaletra comprimidos kaletra comprimidos  119557.0  ...           E
# 21  kaletra comprimidos kaletra comprimidos  119555.0  ...           E
# 22  kaletra comprimidos kaletra comprimidos  119555.0  ...           E
# 23                                ritonavir  119560.0  ...           E
# 24                                  maviret  119558.0  ...           E
# 25                      venclexta venclexta  119572.0  ...           E
# 26                      venclexta venclexta  119572.0  ...           E
# 27                      venclexta venclexta  119572.0  ...           E
# 28                                venclexta  119572.0  ...           E
# 29                                venclexta  119572.0  ...           E
# 30                                venclexta  119572.0  ...           E
# 31                                venclexta  119575.0  ...           E
# 32                                 sevorane  119561.0  ...           E
# 33                                 sevorane  119561.0  ...           E
# 34                                 sevorane  119563.0  ...           E
# 35                      sevorane quick fill  119561.0  ...           E
# 36                      sevorane quick fill  119561.0  ...           E
# 37                      sevorane quick fill  119563.0  ...           E
# 38                                 survanta  119566.0  ...           E
# 39                                 survanta  119566.0  ...           E
# 40                                 survanta  119566.0  ...           E
# 41                                 survanta  119566.0  ...           E
# 42                                  zemplar  119577.0  ...           E
# 43                                  zemplar  119578.0  ...           E
# 44                                  zemplar  119578.0  ...           E
# 45                                  zemplar  119577.0  ...           E
# 46                                  zemplar  119578.0  ...           E
# 47                                  zemplar  119578.0  ...           E
# 48                                    botox   23432.0  ...           E
# 49                                    botox   23432.0  ...           E
# 50                                    botox   23432.0  ...           E
# 51                                    botox   23432.0  ...           E
# 52                                  ozurdex   23459.0  ...           E
#
#    pc_diftrans cod_cvta cat_item cant_rep pto_rep           atrib0 atrib1  \
# 0          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 1          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 2          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 3          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 4          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 5          0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 6          NaN      NaN     None     None     NaN             None    NaN
# 7          NaN      NaN     None     None     NaN             None    NaN
# 8          0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 9          0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 10         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 11         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 12         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 13         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 14         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 15         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 16         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 17         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 18         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 19         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 20         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 21         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 22         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 23         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 24         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 25         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 26         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 27         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 28         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 29         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 30         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 31         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 32         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 33         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 34         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 35         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 36         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 37         0.0      NaN    ITGEV      0.0     0.0           ABBVIE    NaN
# 38         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 39         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 40         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 41         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 42         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 43         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 44         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 45         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 46         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 47         0.0      NaN    ITGEV        0     0.0           ABBVIE    NaN
# 48         0.0      NaN    ITGEV        0     0.0  ABBVIE ALLERGAN    NaN
# 49         0.0      NaN    ITGEV        0     0.0  ABBVIE ALLERGAN    NaN
# 50         0.0      NaN    ITGEV        0     0.0  ABBVIE ALLERGAN    NaN
# 51         0.0      NaN    ITGEV        0     0.0  ABBVIE ALLERGAN    NaN
# 52         0.0      NaN    ITGEV      0.0     0.0  ABBVIE ALLERGAN    NaN
#
#    atrib2                  descrip1_limpia
# 0     NaN               humira  / lapprell
# 1     NaN               humira  / jerprell
# 2     NaN               humira  / lapprell
# 3     NaN                  humira jgaprell
# 4     NaN                humira pediatrico
# 5     NaN              humira pen lapicera
# 6     NaN                             None
# 7     NaN                             None
# 8     NaN                   rinvoq libprol
# 9     NaN                   rinvoq libprol
# 10    NaN                   rinvoq libprol
# 11    NaN                 skyrizi lapprell
# 12    NaN               skyrizi cart + iny
# 13    NaN                          skyrizi
# 14    NaN                 skyrizi jgaprell
# 15    NaN                 skyrizi lapprell
# 16    NaN               skyrizi cart + iny
# 17    NaN                          skyrizi
# 18    NaN                 skyrizi jgaprell
# 19    NaN                          kaletra
# 20    NaN                          kaletra
# 21    NaN                    kaletra / rec
# 22    NaN                    kaletra / rec
# 23    NaN                    ritonavir rec
# 24    NaN                      maviret rec
# 25    NaN                        venclexta
# 26    NaN                        venclexta
# 27    NaN                        venclexta
# 28    NaN                        venclexta
# 29    NaN                        venclexta
# 30    NaN                        venclexta
# 31    NaN            venclexta kit  inicio
# 32    NaN                         sevorane
# 33    NaN                         sevorane
# 34    NaN              sevorane quick fill
# 35    NaN                         sevorane
# 36    NaN                         sevorane
# 37    NaN              sevorane quick fill
# 38    NaN                         survanta
# 39    NaN                         survanta
# 40    NaN                         survanta
# 41    NaN                         survanta
# 42    NaN                     zemplar cáps
# 43    NaN                          zemplar
# 44    NaN                          zemplar
# 45    NaN                     zemplar cáps
# 46    NaN                          zemplar
# 47    NaN                          zemplar
# 48    NaN                          botox u
# 49    NaN                          botox u
# 50    NaN                          botox u
# 51    NaN                          botox u
# 52    NaN  ozurdex implante oftintravítrea
#
# [53 rows x 56 columns]

# %%
# Mostrar las coincidencias que no cumplen con el umbral de similitud
df_matches[df_matches['similaridad'] < 80]
# Out:
#    similaridad                    Unnamed: 0  \
# 6          0.0  20015888\n20005289\n20021980
# 7          0.0  20062091\n20069005\n20078725
#
#                                   DESCRIPCIÓN  \
# 6  HUMIRA AC x 2 (40mg) HUMIRA AC x 1 (80 mg)
# 7                     RINVOQ 15MG RINVOQ 30MG
#
#                                         PRESENTACION  \
# 6  2 JERINGAS PRELL. X 0,2 ml\n2 LAPICERAS PRELL....
# 7  15 MG x 30 COMP REC DE LIB. PROLONGADA\n30 MG ...
#
#                               CODIGO DE BARRAS  \
# 6  8054083017068\n8054083014050\n8054083017648
# 7  8054083018706\n8054083021386\n8054083023922
#
#                                       PRECIO CON IVA  \
# 6  $             740,145.59\n$         1,480,292....
# 7  $         1,799,606.71\n$         3,184,521.02...
#
#                                       PRECIO SIN IVA  \
# 6  $             611,690.58\n$          1,223,382...
# 7  $          1,487,278.28\n$          2,631,835....
#
#                                    PUBLICO\nSUGERIDO descripcion_limpia  \
# 6  $           1,073,211.02\n$           2,146,42...    humira   humira
# 7  $           2,609,429.58\n$           4,617,55...    rinvoq  rinvoq
#
#    niprod  ... tipo_egreso pc_diftrans cod_cvta cat_item cant_rep pto_rep  \
# 6     NaN  ...        None         NaN      NaN     None     None     NaN
# 7     NaN  ...        None         NaN      NaN     None     None     NaN
#
#   atrib0 atrib1 atrib2  descrip1_limpia
# 6   None    NaN    NaN             None
# 7   None    NaN    NaN             None
#
# [2 rows x 56 columns]
